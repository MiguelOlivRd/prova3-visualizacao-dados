# %%
import pandas as pd

railway = pd.read_csv("railway.csv")
viagens_atrasadas = pd.read_csv("viagens_atrasadas.csv")

mapa_colunas = {
    "Transaction ID": "ID",
    "Departure Station": "ESTACAO_IDA",
    "Arrival Destination": "ESTACAO_CHEGADA",
    "Date of Journey": "DATA_VIAGEM",
    "Departure Time": "HORARIO_SAIDA",
    "Arrival Time": "TEMPO_ESPERADO_DA_VIAGEM",
    "Actual Arrival Time": "HORARIO_CHEGADA",
    "Journey Status": "Status da Jornada",
    "Reason for Delay": "MOTIVO_ATRASO",
    "Price": "PRECO_MEDIO",
    # As demais colunas do original não têm correspondência no traduzido
}

railway = railway.rename(columns=mapa_colunas)

# %%
print("original: " + str(list(railway.columns)))
print("traduzido com alterações: " + str(list(viagens_atrasadas.columns)))
# Out:
# original: ['ID', 'Date of Purchase', 'Time of Purchase', 'Purchase Type', 'Payment Method', 'Railcard', 'Ticket Class', 'Ticket Type', 'PRECO_MEDIO', 'ESTACAO_IDA', 'ESTACAO_CHEGADA', 'DATA_VIAGEM', 'HORARIO_SAIDA', 'TEMPO_ESPERADO_DA_VIAGEM', 'HORARIO_CHEGADA', 'Status da Jornada', 'MOTIVO_ATRASO', 'Refund Request']
# traduzido com alterações: ['ID', 'Date of Purchase', 'Time of Purchase', 'Purchase Type', 'Payment Method', 'Railcard', 'Ticket Class', 'Ticket Type', 'PRECO_MEDIO', 'ESTACAO_IDA', 'ESTACAO_CHEGADA', 'DATA_VIAGEM', 'HORARIO_SAIDA', 'TEMPO_ESPERADO_DA_VIAGEM', 'HORARIO_CHEGADA', 'Status da Jornada', 'MOTIVO_ATRASO', 'Refund Request', 'ATRASO']

# %%
import pandas as pd

# Não é necessário converter as colunas para datetime/timedelta aqui
# Calcular o atraso em minutos sem alterar os tipos das outras colunas

# Converter apenas as colunas necessárias para datetime
horario_chegada = pd.to_datetime(railway['HORARIO_CHEGADA'], format='%H:%M:%S', errors='coerce')
tempo_esperado = pd.to_datetime(railway['TEMPO_ESPERADO_DA_VIAGEM'], format='%H:%M:%S', errors='coerce')

# Calcular a diferença em minutos
railway['ATRASO'] = (horario_chegada - tempo_esperado).dt.total_seconds() / 60

# %%
railway.head()
# Out:
#                         ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  PRECO_MEDIO  \
# 0    Contactless    Adult     Standard     Advance           43
# 1    Credit Card    Adult     Standard     Advance           23
# 2    Credit Card      NaN     Standard     Advance            3
# 3    Credit Card      NaN     Standard     Advance           13
# 4    Contactless      NaN     Standard     Advance           76
#
#              ESTACAO_IDA        ESTACAO_CHEGADA DATA_VIAGEM HORARIO_SAIDA  \
# 0      London Paddington  Liverpool Lime Street  2024-01-01      11:00:00
# 1     London Kings Cross                   York  2024-01-01      09:45:00
# 2  Liverpool Lime Street  Manchester Piccadilly  2024-01-02      18:15:00
# 3      London Paddington                Reading  2024-01-01      21:30:00
# 4  Liverpool Lime Street          London Euston  2024-01-01      16:45:00
#
#   TEMPO_ESPERADO_DA_VIAGEM HORARIO_CHEGADA Status da Jornada   MOTIVO_ATRASO  \
# 0                 13:30:00        13:30:00           On Time             NaN
# 1                 11:35:00        11:40:00           Delayed  Signal Failure
# 2                 18:45:00        18:45:00           On Time             NaN
# 3                 22:30:00        22:30:00           On Time             NaN
# 4                 19:00:00        19:00:00           On Time             NaN
#
#   Refund Request  ATRASO
# 0             No     0.0
# 1             No     5.0
# 2             No     0.0
# 3             No     0.0
# 4             No     0.0

# %%
railway = railway.dropna(subset=['ATRASO'])

# %%
railway.to_csv("viagens_atrasadas.csv", index=False)

# %%
import pandas as pd

atrasos = pd.read_csv("viagens_atrasadas.csv")

# %%
def start_to_end(start, end):
    return atrasos[(atrasos["ESTACAO_IDA"] == start) & (atrasos["ESTACAO_CHEGADA"] == end)]

start_to_end("York", "Birmingham New Street")[0:20]
# Out:
#                             ID Date of Purchase Time of Purchase  \
# 352    cd046d0a-8cfd-4268-96c6       2024-01-03         02:20:52
# 6090   5c2ba502-bf26-4f49-a955       2024-01-25         02:21:04
# 8323   7a16990e-fa9f-47cb-8271       2024-02-02         05:26:18
# 10009  ddf76ef4-ad71-406a-9a10       2024-02-06         05:23:40
# 11852  05720738-ec44-4ee7-b5f3       2024-02-11         05:21:56
# 14969  36deb342-5cae-4601-a167       2024-03-02         02:28:47
# 17283  02875065-adfe-4237-8bb2       2024-03-11         02:24:56
# 18571  10db7283-155c-47f8-b0ce       2024-03-16         05:18:31
# 20331  919a0ecf-48e3-44ab-8fab       2024-03-23         02:22:54
# 21131  056cf741-782c-4100-9dc3       2024-03-26         02:21:05
# 21159  31bdeab2-f02b-4f59-b831       2024-03-26         05:17:33
# 22117  600cbdc7-2848-405e-98ea       2024-03-30         02:27:38
# 24816  a2da49dc-2dd7-4b23-b098       2024-04-11         05:27:02
# 29429  3ea33e86-34c4-4562-b34c       2024-04-29         02:19:59
#
#       Purchase Type Payment Method Railcard Ticket Class Ticket Type  \
# 352          Online    Contactless      NaN     Standard    Off-Peak
# 6090         Online    Contactless      NaN     Standard    Off-Peak
# 8323         Online    Contactless      NaN     Standard     Advance
# 10009        Online    Contactless      NaN     Standard     Advance
# 11852        Online    Contactless      NaN     Standard     Advance
# 14969        Online    Contactless      NaN     Standard    Off-Peak
# 17283        Online    Contactless      NaN     Standard    Off-Peak
# 18571        Online    Contactless      NaN     Standard     Advance
# 20331        Online    Contactless      NaN     Standard    Off-Peak
# 21131        Online    Contactless      NaN  First Class    Off-Peak
# 21159        Online    Contactless      NaN     Standard     Advance
# 22117        Online    Contactless      NaN     Standard    Off-Peak
# 24816        Online    Contactless      NaN     Standard     Advance
# 29429        Online    Contactless      NaN     Standard    Off-Peak
#
#        PRECO_MEDIO ESTACAO_IDA        ESTACAO_CHEGADA DATA_VIAGEM  \
# 352             59        York  Birmingham New Street  2024-01-03
# 6090            59        York  Birmingham New Street  2024-01-25
# 8323            39        York  Birmingham New Street  2024-02-26
# 10009           39        York  Birmingham New Street  2024-02-21
# 11852           39        York  Birmingham New Street  2024-02-12
# 14969           59        York  Birmingham New Street  2024-03-02
# 17283           59        York  Birmingham New Street  2024-03-11
# 18571           39        York  Birmingham New Street  2024-03-17
# 20331           59        York  Birmingham New Street  2024-03-23
# 21131           74        York  Birmingham New Street  2024-03-26
# 21159           39        York  Birmingham New Street  2024-03-27
# 22117           59        York  Birmingham New Street  2024-03-30
# 24816           39        York  Birmingham New Street  2024-04-12
# 29429           59        York  Birmingham New Street  2024-04-29
#
#       HORARIO_SAIDA TEMPO_ESPERADO_DA_VIAGEM HORARIO_CHEGADA  \
# 352        03:45:00                 06:00:00        06:00:00
# 6090       03:45:00                 06:00:00        06:00:00
# 8323       03:45:00                 06:00:00        06:00:00
# 10009      03:45:00                 06:00:00        06:00:00
# 11852      03:45:00                 06:00:00        06:00:00
# 14969      03:45:00                 06:00:00        06:00:00
# 17283      03:45:00                 06:00:00        06:00:00
# 18571      03:45:00                 06:00:00        06:00:00
# 20331      03:45:00                 06:00:00        06:00:00
# 21131      03:45:00                 06:00:00        06:00:00
# 21159      03:45:00                 06:00:00        06:00:00
# 22117      03:45:00                 06:00:00        06:00:00
# 24816      03:45:00                 06:00:00        06:00:00
# 29429      03:45:00                 06:00:00        06:00:00
#
#       Status da Jornada MOTIVO_ATRASO Refund Request  ATRASO
# 352             On Time           NaN             No     0.0
# 6090            On Time           NaN             No     0.0
# 8323            On Time           NaN             No     0.0
# 10009           On Time           NaN             No     0.0
# 11852           On Time           NaN             No     0.0
# 14969           On Time           NaN             No     0.0
# 17283           On Time           NaN             No     0.0
# 18571           On Time           NaN             No     0.0
# 20331           On Time           NaN             No     0.0
# 21131           On Time           NaN             No     0.0
# 21159           On Time           NaN             No     0.0
# 22117           On Time           NaN             No     0.0
# 24816           On Time           NaN             No     0.0
# 29429           On Time           NaN             No     0.0
